# %%
import glob
import os
import pandas as pd

path ='.../data' # use your path
allFiles = glob.glob("data/*.csv")

list_ = []
name=[]

for file_ in allFiles:
#     name.append(os.path.basename(file_))
    df = pd.read_csv(file_, header=0,usecols = ['Close'])
    
#     list_.append(df)

# frame = pd.concat(list_, axis = 1, ignore_index = True)
# frame.columns=[name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _handle_usecols(self, columns, usecols_key)
#    2509                         try:
# -> 2510                             col_indices.append(usecols_key.index(col))
#    2511                         except ValueError:
#
# ValueError: 'Close' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-86b35737743e> in <module>
#      11 for file_ in allFiles:
#      12 #     name.append(os.path.basename(file_))
# ---> 13     df = pd.read_csv(file_, header=0,usecols = ['Close'],engine='python')
#      14
#      15 #     list_.append(df)
#
# ...

# %%
list_[:3]
# Out:
# [           Date    Open    High          Low   Close    Adj Close     Volume
#  0    2016-02-19  2487.0  2494.0  2421.000000  2460.0  2229.962891   356040.0
#  1    2016-02-22  2465.0  2516.0  2459.000000  2503.0  2268.941895   218841.0
#  2    2016-02-23  2525.0  2531.0  2483.000000  2505.0  2270.754639   326460.0
#  3    2016-02-24  2492.0  2498.0  2463.000000  2473.0  2241.747070   459857.0
#  4    2016-02-25  2517.0  2561.0  2497.000000  2557.0  2317.892090   380506.0
#  5    2016-02-26  2581.0  2641.0  2581.000000  2640.0  2393.130859   414925.0
#  6    2016-02-29  2597.0  2616.0  2568.000000  2616.0  2371.374756   315579.0
#  7    2016-03-01  2603.0  2687.0  2600.000000  2687.0  2435.735840   314164.0
#  8    2016-03-02  2685.0  2767.0  2685.000000  2718.0  2463.836914   392474.0
#  9    2016-03-03  2781.0  2836.0  2700.000000  2738.0  2481.966797   523997.0
#  10   2016-03-04  2712.0  2718.0  2620.000000  2624.0  2378.626709   644066.0
# ...

# %%
df = pd.read_csv('data/AHT.L.csv', header=0,usecols = ['Date','Close'])

# %%
df[:3]
# Out:
#          Date  Close
# 0  2016-02-19  846.5
# 1  2016-02-22  879.0
# 2  2016-02-23  876.0

# %%
# frame.to_csv(final.csv, encoding='utf-8')
frame.to_csv("output.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv('output.csv')

# %%
df[:2]
# Out:
#    SDR.L.csv  NMC.L.csv    CPG.L.csv  PRU.L.csv  STJ.L.csv    WWD.csv  \
# 0     2460.0      800.0  1278.160034     1229.5      892.0  46.660000
# 1     2503.0      794.0  1294.800049     1253.5      899.0  46.360001
#
#     EBAY.csv  EZJ.L.csv  CCL.L.csv  EXPN.L.csv     ...      GVC.L.csv  \
# 0  32.900002     1553.0     3313.0      1162.0     ...         460.75
# 1  32.610001     1545.0     3417.0      1184.0     ...         468.50
#
#    AHT.L.csv  RB.L.csv  SMT.L.csv  PPB.L.csv  SPX.L.csv  BA.L.csv   DLG.L.csv  \
# 0      846.5    6556.0    2.40758    10100.0     3038.0     505.5  374.700012
# 1      879.0    6582.0    2.48168    10320.0     3082.0     510.0  378.200012
#
#    LLOY.L.csv   RMV.L.csv
# 0   61.799999  374.000000
# 1   63.119999  371.799988
#
# [2 rows x 30 columns]

# %%
for n in glob.glob("data/*.csv"):
    print(n)
# Out:
# data/SDR.L.csv
# data/NMC.L.csv
# data/CPG.L.csv
# data/PRU.L.csv
# data/STJ.L.csv
# data/WWD.csv
# data/EBAY.csv
# data/EZJ.L.csv
# data/CCL.L.csv
# data/EXPN.L.csv
# data/SMIN.L.csv
# data/TSCO.L-2.csv
# data/SSE.L.csv
# data/AUTO.L.csv
# data/TUI.L.csv
# data/EA.csv
# data/CCH.L.csv
# data/RTO.L.csv
# data/VOD.L.csv
# data/BATS.L.csv
# data/GVC.L.csv
# data/AHT.L.csv
# data/RB.L.csv
# data/SMT.L.csv
# data/PPB.L.csv
# data/SPX.L.csv
# data/BA.L.csv
# data/DLG.L.csv
# data/LLOY.L.csv
# data/RMV.L.csv

# %%
a=[]
for file_ in glob.glob("data/*.csv"):
    a.append(os.path.basename(file_))

# %%
a
# Out:
# ['SDR.L.csv',
#  'NMC.L.csv',
#  'CPG.L.csv',
#  'PRU.L.csv',
#  'STJ.L.csv',
#  'WWD.csv',
#  'EZJ.L.csv',
#  'CCL.L.csv',
#  'EXPN.L.csv',
#  'SMIN.L.csv',
#  'TSCO.L-2.csv',
#  'SSE.L.csv',
#  'AUTO.L.csv',
#  'TUI.L.csv',
#  'CCH.L.csv',
#  'RTO.L.csv',
#  'output.csv',
#  'VOD.L.csv',
#  'BATS.L.csv',
#  'GVC.L.csv',
#  'AHT.L.csv',
#  'RB.L.csv',
#  'SMT.L.csv',
#  'PPB.L.csv',
#  'SPX.L.csv',
#  'BRBY.L.csv',
#  'BA.L.csv',
#  'DLG.L.csv',
#  'LLOY.L.csv',
#  'ASBFY.csv',
#  'RMV.L.csv']
